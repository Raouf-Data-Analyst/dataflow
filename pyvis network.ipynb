# %%
import json
import networkx as nx
from pyvis.network import Network
import streamlit as st

data = """
{
    "XXXJYGYLBP": {
        "inputs": [
            "XXXJZMANJY",
            "XXXJNVSFXW",
            "XXXJVYPKUA"
        ],
        "outputs": [
            "XXXJVQUYNB",
            "XXXJKTZUJA",
            "XXXJHEBIOV",
            "XXXJDGENJJ"
        ],
        "name": "XXXJYGYLBP",
        "label": "While school rate similar together hard model.",
        "uprocs": [
            {
                "name": "XXXJSDVDD",
                "label": "Still first.",
                "script": "management.ksh",
                "dep": {
                    "upr": [
                        "XXXJNUDRY",
                        "XXXJMHQUC",
                        "XXXJMBSFG"
                    ]
                },
                "table_deps": {
                    "INTER.KLT_T_AQXNPUV": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.USN_R_KRDRVOJK",
                        "VISION.EJH_A_PBTTHZET",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.UOC_F_QMTYPUVF"
                    ]
                }
            },
            {
                "name": "XXXJEPYWX",
                "label": "Purpose approach.",
                "script": "more.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.RHC_T_SKKFNYZ": [
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.ZNF_R_QZQTENZM",
                        "VISION.KKJ_A_FQELHEJF"
                    ]
                }
            },
            {
                "name": "XXXJTNCPH",
                "label": "Enough ten.",
                "script": "information.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.RSI_T_TZPNIWZ": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.FXY_F_QMJHIEML",
                        "BASE.QWJ_R_NIQXWDSX",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.PJO_R_EFKGXBCN"
                    ]
                }
            },
            {
                "name": "XXXJSLSPZ",
                "label": "Minute.",
                "script": "to.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJSDVDD , XXXJEPYWX ;XXXJEPYWX , XXXJTNCPH ;XXXJTNCPH , XXXJSLSPZ ;;; "
    },
    "XXXJVOCYGI": {
        "inputs": [
            "XXXJBOJLCT"
        ],
        "outputs": [
            "XXXJTFQHDL",
            "XXXJRKIPAN",
            "XXXJHWPKNB"
        ],
        "name": "XXXJVOCYGI",
        "label": "Scene such already really government.",
        "uprocs": [
            {
                "name": "XXXJYRHJI",
                "label": "Bag avoid.",
                "script": "consumer.ksh",
                "dep": {
                    "upr": [
                        "XXXJGSHNU"
                    ]
                },
                "table_deps": {
                    "INTER.MBL_T_WUUTVEQ": [
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.QHR_R_OJMFEOXE",
                        "VISION.EJH_A_PBTTHZET"
                    ]
                }
            },
            {
                "name": "XXXJTXHTT",
                "label": "Perhaps.",
                "script": "reduce.ksh",
                "dep": {
                    "upr": [
                        "XXXJYRHJI"
                    ]
                },
                "table_deps": {
                    "INTER.GVK_T_KLRRRQB": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.ZNF_R_QZQTENZM",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.QWJ_R_NIQXWDSX",
                        "VISION.KKJ_A_FQELHEJF"
                    ]
                }
            },
            {
                "name": "XXXJSYEFB",
                "label": "Truth town.",
                "script": "fact.ksh",
                "dep": {
                    "upr": [
                        "XXXJTXHTT"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJCISGE",
                "label": "Whose clear.",
                "script": "support.ksh",
                "dep": {
                    "upr": [
                        "XXXJSYEFB"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJYRHJI , XXXJTXHTT ;XXXJTXHTT , XXXJSYEFB ;XXXJSYEFB , XXXJCISGE ;;; "
    },
    "XXXJZAJAOE": {
        "inputs": [
            "XXXJHWPKNB"
        ],
        "outputs": [
            "XXXJMYWBPH"
        ],
        "name": "XXXJZAJAOE",
        "label": "Help fish prove marriage challenge car.",
        "uprocs": [
            {
                "name": "XXXJJLVMH",
                "label": "Imagine.",
                "script": "note.ksh",
                "dep": {
                    "upr": [
                        "XXXJCEQIN"
                    ]
                },
                "table_deps": {
                    "INTER.RDG_T_GTYDIIR": [
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.EJH_A_PBTTHZET",
                        "VISION.DSE_A_GKDGBHBR",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.OWN_R_RNFYEAIM",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.ZNF_R_QZQTENZM"
                    ]
                }
            },
            {
                "name": "XXXJLBPET",
                "label": "Once.",
                "script": "ready.ksh",
                "dep": {
                    "upr": [
                        "XXXJJLVMH"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJSVOXV",
                "label": "Trial.",
                "script": "course.ksh",
                "dep": {
                    "upr": [
                        "XXXJJLVMH"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJBIEMQ",
                "label": "Memory no.",
                "script": "little.ksh",
                "dep": {
                    "upr": [
                        "XXXJLBPET",
                        "XXXJSVOXV"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJJLVMH , XXXJLBPET ;XXXJLBPET , XXXJSVOXV ;XXXJSVOXV , XXXJBIEMQ ;;; "
    },
    "XXXJGSACLH": {
        "inputs": [
            "XXXJVQUYNB",
            "XXXJKTZUJA",
            "XXXJHEBIOV",
            "XXXJDGENJJ"
        ],
        "outputs": [
            "XXXJMYWBPH"
        ],
        "name": "XXXJGSACLH",
        "label": "More up computer public.",
        "uprocs": [
            {
                "name": "XXXJVNGSW",
                "label": "Relate.",
                "script": "above.ksh",
                "dep": {
                    "upr": [
                        "XXXJKAMYQ",
                        "XXXJUTEWL",
                        "XXXJHKGDI",
                        "XXXJCFMFW"
                    ]
                },
                "table_deps": {
                    "INTER.KCT_T_ZAFHSGG": [
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.DSE_A_GKDGBHBR",
                        "VISION.EJH_A_PBTTHZET",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.OWN_R_RNFYEAIM",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.ZNF_R_QZQTENZM"
                    ]
                }
            },
            {
                "name": "XXXJNSERL",
                "label": "Floor.",
                "script": "never.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJVAOGO",
                "label": "Task.",
                "script": "wind.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJVNGSW , XXXJNSERL ;XXXJNSERL , XXXJVAOGO ;;; "
    },
    "XXXJRKIPAN": {
        "inputs": [
            "XXXJVOCYGI"
        ],
        "outputs": [
            "XXXJMYWBPH"
        ],
        "name": "XXXJRKIPAN",
        "label": "Strategy toward because summer may.",
        "uprocs": [
            {
                "name": "XXXJIRDTZ",
                "label": "Wait.",
                "script": "campaign.ksh",
                "dep": {
                    "upr": [
                        "XXXJCISGE"
                    ]
                },
                "table_deps": {
                    "INTER.JMZ_T_HLVIKJV": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.USN_R_KRDRVOJK",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.QWJ_R_NIQXWDSX",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.OWN_R_RNFYEAIM",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.ZNF_R_QZQTENZM"
                    ]
                }
            },
            {
                "name": "XXXJRKIPAN",
                "label": "Voice.",
                "script": "although.ksh",
                "dep": {
                    "upr": [
                        "XXXJIRDTZ"
                    ]
                },
                "table_deps": {
                    "INTER.QPD_T_VMVGKYG": [
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.FXY_F_QMJHIEML"
                    ]
                }
            },
            {
                "name": "XXXJWYOXD",
                "label": "Within box.",
                "script": "history.ksh",
                "dep": {
                    "upr": [
                        "XXXJRKIPAN"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJIRDTZ , XXXJRKIPAN ;XXXJRKIPAN , XXXJWYOXD ;;; "
    },
    "XXXJHBOCQC": {
        "inputs": [
            "XXXJNVSFXW",
            "XXXJVYPKUA"
        ],
        "outputs": [
            "XXXJTFQHDL",
            "XXXJMYWBPH"
        ],
        "name": "XXXJHBOCQC",
        "label": "Building commercial performance section picture happy.",
        "uprocs": [
            {
                "name": "XXXJOTBSZ",
                "label": "Shoulder.",
                "script": "author.ksh",
                "dep": {
                    "upr": [
                        "XXXJMHQUC",
                        "XXXJNUDRY"
                    ]
                },
                "table_deps": {
                    "INTER.GIN_T_HZFLBBC": [
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.OWN_R_RNFYEAIM"
                    ]
                }
            },
            {
                "name": "XXXJHBOCQC",
                "label": "Probably.",
                "script": "available.ksh",
                "dep": {
                    "upr": [
                        "XXXJOTBSZ"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJFRHOP",
                "label": "Human system.",
                "script": "right.ksh",
                "dep": {
                    "upr": [
                        "XXXJHBOCQC"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJOTBSZ , XXXJHBOCQC ;XXXJHBOCQC , XXXJFRHOP ;;; "
    },
    "XXXJZMANJY": {
        "inputs": [
            "XXXJTFQHDL"
        ],
        "outputs": [
            "XXXJZSCVBF",
            "XXXJYGYLBP"
        ],
        "name": "XXXJZMANJY",
        "label": "Policy establish ahead southern though student time.",
        "uprocs": [
            {
                "name": "XXXJFFYZO",
                "label": "Doctor draw.",
                "script": "mind.ksh",
                "dep": {
                    "upr": [
                        "XXXJBUZWB"
                    ]
                },
                "table_deps": {
                    "INTER.ZJT_T_VSMFOIT": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJZMANJY",
                "label": "Size result.",
                "script": "radio.ksh",
                "dep": {
                    "upr": [
                        "XXXJFFYZO"
                    ]
                },
                "table_deps": {
                    "INTER.SFK_T_AYVDYVC": [
                        "BASE.QHR_R_OJMFEOXE",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.XZK_F_IHGDDHGG"
                    ]
                }
            },
            {
                "name": "XXXJRHGKA",
                "label": "Special.",
                "script": "forward.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMBSFG",
                "label": "Camera.",
                "script": "size.ksh",
                "dep": {
                    "upr": [
                        "XXXJZMANJY"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJFFYZO , XXXJZMANJY ;XXXJZMANJY , XXXJRHGKA ;XXXJRHGKA , XXXJMBSFG ;;; "
    },
    "XXXJVYPKUA": {
        "inputs": [
            "XXXJZSCVBF"
        ],
        "outputs": [
            "XXXJTFQHDL",
            "XXXJHBOCQC",
            "XXXJMYWBPH",
            "XXXJYGYLBP"
        ],
        "name": "XXXJVYPKUA",
        "label": "Rock last by including me.",
        "uprocs": [
            {
                "name": "XXXJUFGMD",
                "label": "Hear.",
                "script": "language.ksh",
                "dep": {
                    "upr": [
                        "XXXJMXBTL"
                    ]
                },
                "table_deps": {
                    "INTER.AEE_T_HTRZDSL": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.QWJ_R_NIQXWDSX"
                    ]
                }
            },
            {
                "name": "XXXJVYPKUA",
                "label": "Help enjoy.",
                "script": "respond.ksh",
                "dep": {
                    "upr": [
                        "XXXJUFGMD"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJNUDRY",
                "label": "Cold.",
                "script": "ever.ksh",
                "dep": {
                    "upr": [
                        "XXXJVYPKUA"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJUFGMD , XXXJVYPKUA ;XXXJVYPKUA , XXXJNUDRY ;;; "
    },
    "XXXJMYWBPH": {
        "inputs": [
            "XXXJTFQHDL",
            "XXXJHBOCQC",
            "XXXJNVSFXW",
            "XXXJVYPKUA",
            "XXXJRKIPAN",
            "XXXJHWPKNB",
            "XXXJZAJAOE",
            "XXXJGSACLH"
        ],
        "outputs": [],
        "name": "XXXJMYWBPH",
        "label": "Public compare individual next front minute.",
        "uprocs": [
            {
                "name": "XXXJQGQWS",
                "label": "White picture.",
                "script": "building.ksh",
                "dep": {
                    "upr": [
                        "XXXJCEQIN",
                        "XXXJDKSIH",
                        "XXXJMHQUC",
                        "XXXJNUDRY",
                        "XXXJWYOXD",
                        "XXXJFRHOP",
                        "XXXJBIEMQ",
                        "XXXJVAOGO"
                    ]
                },
                "table_deps": {
                    "INTER.TCR_T_KHMTLHD": [
                        "VISION.EJH_A_PBTTHZET",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.QWJ_R_NIQXWDSX",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.OWN_R_RNFYEAIM",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.QHR_R_OJMFEOXE",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.PJO_R_EFKGXBCN"
                    ]
                }
            },
            {
                "name": "XXXJMYWBPH",
                "label": "Ability.",
                "script": "nothing.ksh",
                "dep": {
                    "upr": [
                        "XXXJQGQWS"
                    ]
                },
                "table_deps": {
                    "INTER.FSQ_T_ETPTVRN": [
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.XZK_F_IHGDDHGG",
                        "VISION.EJH_A_PBTTHZET"
                    ]
                }
            },
            {
                "name": "XXXJUCESC",
                "label": "Cover.",
                "script": "job.ksh",
                "dep": {
                    "upr": [
                        "XXXJMYWBPH"
                    ]
                },
                "table_deps": {
                    "INTER.UEE_T_ETGRAPH": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJYUHFC",
                "label": "Toward life.",
                "script": "generation.ksh",
                "dep": {
                    "upr": [
                        "XXXJUCESC"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJQGQWS , XXXJMYWBPH ;XXXJMYWBPH , XXXJUCESC ; , XXXJYUHFC ;;; "
    },
    "XXXJDGENJJ": {
        "inputs": [
            "XXXJYGYLBP"
        ],
        "outputs": [
            "XXXJGSACLH"
        ],
        "name": "XXXJDGENJJ",
        "label": "And people big political tonight month door also.",
        "uprocs": [
            {
                "name": "XXXJDNKTJ",
                "label": "Rise hair.",
                "script": "compare.ksh",
                "dep": {
                    "upr": [
                        "XXXJSLSPZ"
                    ]
                },
                "table_deps": {
                    "INTER.SLV_T_HFMQWPH": [
                        "BASE.TWV_R_FKJIDEIR",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.QHR_R_OJMFEOXE",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.QWJ_R_NIQXWDSX"
                    ]
                }
            },
            {
                "name": "XXXJNUOQY",
                "label": "Space.",
                "script": "have.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJLAGKW",
                "label": "Agreement.",
                "script": "form.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJBKIWN",
                "label": "Billion.",
                "script": "market.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJRFFMF",
                "label": "Need college.",
                "script": "design.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJBDSVN",
                "label": "First.",
                "script": "now.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJUIBGC",
                "label": "Reality.",
                "script": "that.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJIOTUC",
                "label": "How also.",
                "script": "throughout.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJCGFHZ",
                "label": "Onto.",
                "script": "sure.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMOFUO",
                "label": "Quickly.",
                "script": "doctor.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJPAGQX",
                "label": "Notice if.",
                "script": "part.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJDSGCQ",
                "label": "Western.",
                "script": "mission.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJOJHHL",
                "label": "Always.",
                "script": "lay.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJHKGDI",
                "label": "But side.",
                "script": "live.ksh",
                "dep": {
                    "upr": [
                        "XXXJLAGKW",
                        "XXXJBKIWN",
                        "XXXJRFFMF",
                        "XXXJBDSVN",
                        "XXXJUIBGC",
                        "XXXJIOTUC",
                        "XXXJCGFHZ",
                        "XXXJMOFUO",
                        "XXXJPAGQX",
                        "XXXJDSGCQ"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJDNKTJ , XXXJNUOQY ; , XXXJOJHHL ;XXXJNUOQY , XXXJLAGKW ; , XXXJBKIWN ; , XXXJRFFMF ; , XXXJBDSVN ; , XXXJUIBGC ; , XXXJIOTUC ; , XXXJCGFHZ ; , XXXJMOFUO ; , XXXJPAGQX ; , XXXJDSGCQ ;XXXJOJHHL , XXXJHKGDI ;;; "
    },
    "XXXJHWPKNB": {
        "inputs": [
            "XXXJZSCVBF",
            "XXXJVOCYGI"
        ],
        "outputs": [
            "XXXJZAJAOE",
            "XXXJMYWBPH"
        ],
        "name": "XXXJHWPKNB",
        "label": "Cause design federal small prove.",
        "uprocs": [
            {
                "name": "XXXJMMKRC",
                "label": "Rest believe.",
                "script": "fight.ksh",
                "dep": {
                    "upr": [
                        "XXXJCISGE"
                    ]
                },
                "table_deps": {
                    "INTER.RCZ_T_HWETBMM": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.ZNF_R_QZQTENZM",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.UOC_F_QMTYPUVF"
                    ]
                }
            },
            {
                "name": "XXXJHWPKNB",
                "label": "Order.",
                "script": "both.ksh",
                "dep": {
                    "upr": [
                        "XXXJMMKRC"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJPPRKG",
                "label": "Professional turn.",
                "script": "class.ksh",
                "dep": {
                    "upr": [
                        "XXXJHWPKNB",
                        "XXXJZKEID",
                        "XXXJQRWWW"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJCEQIN",
                "label": "What decade.",
                "script": "drop.ksh",
                "dep": {
                    "upr": [
                        "XXXJPPRKG"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJOABQG",
                "label": "Because where.",
                "script": "Republican.ksh",
                "dep": {
                    "upr": [
                        "XXXJHWPKNB"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJMMKRC , XXXJHWPKNB ; , XXXJOABQG ;XXXJHWPKNB , XXXJPPRKG ;XXXJPPRKG , XXXJCEQIN ;;; "
    },
    "XXXJALBXWD": {
        "inputs": [
            "XXXJZSCVBF"
        ],
        "outputs": [],
        "name": "XXXJALBXWD",
        "label": "Five well mention sometimes role its.",
        "uprocs": [
            {
                "name": "XXXJFEGAW",
                "label": "Fall while.",
                "script": "explain.ksh",
                "dep": {
                    "upr": [
                        "XXXJIRNJW"
                    ]
                },
                "table_deps": {
                    "INTER.SLZ_T_XZCQYZF": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.USN_R_KRDRVOJK",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.ZNF_R_QZQTENZM"
                    ]
                }
            },
            {
                "name": "XXXJKJEGZ",
                "label": "See.",
                "script": "success.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.QXG_T_AOWBYUW": [
                        "BASE.PJO_R_EFKGXBCN",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.ROS_R_QPMFUQVM"
                    ]
                }
            },
            {
                "name": "XXXJYFIBY",
                "label": "Blue.",
                "script": "program.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.ORE_T_QOHBWDZ": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.FFB_F_RQHDIGBN",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.QWJ_R_NIQXWDSX",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.OWN_R_RNFYEAIM"
                    ]
                }
            },
            {
                "name": "XXXJQHGLN",
                "label": "Product every.",
                "script": "house.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJFEGAW , XXXJKJEGZ ;XXXJKJEGZ , XXXJYFIBY ;XXXJYFIBY , XXXJQHGLN ;;; "
    },
    "XXXJKTZUJA": {
        "inputs": [
            "XXXJYGYLBP"
        ],
        "outputs": [
            "XXXJGSACLH"
        ],
        "name": "XXXJKTZUJA",
        "label": "Might only news.",
        "uprocs": [
            {
                "name": "XXXJMSPMF",
                "label": "Visit.",
                "script": "interest.ksh",
                "dep": {
                    "upr": [
                        "XXXJSLSPZ"
                    ]
                },
                "table_deps": {
                    "INTER.MTE_T_AOVNFUV": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.OWN_R_RNFYEAIM",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.ZNF_R_QZQTENZM",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.XZK_F_IHGDDHGG"
                    ]
                }
            },
            {
                "name": "XXXJLHDYP",
                "label": "Discussion team.",
                "script": "western.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.SFS_T_NDPLFPY": [
                        "BASE.UOC_F_QMTYPUVF"
                    ]
                }
            },
            {
                "name": "XXXJTXHWT",
                "label": "Fund.",
                "script": "office.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJICUMK",
                "label": "Know cost.",
                "script": "security.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJAGDAA",
                "label": "City.",
                "script": "order.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJCFMFW",
                "label": "House opportunity.",
                "script": "dog.ksh",
                "dep": {
                    "upr": [
                        "XXXJTXHWT",
                        "XXXJICUMK"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJMSPMF , XXXJLHDYP ; , XXXJAGDAA ;XXXJLHDYP , XXXJTXHWT ; , XXXJICUMK ;XXXJAGDAA , XXXJCFMFW ;;; "
    },
    "XXXJVQUYNB": {
        "inputs": [
            "XXXJYGYLBP"
        ],
        "outputs": [
            "XXXJGSACLH"
        ],
        "name": "XXXJVQUYNB",
        "label": "Including person word so leader throw serve.",
        "uprocs": [
            {
                "name": "XXXJJIFPH",
                "label": "Once these.",
                "script": "in.ksh",
                "dep": {
                    "upr": [
                        "XXXJSLSPZ"
                    ]
                },
                "table_deps": {
                    "INTER.TLI_T_SZNOYTS": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.ELE_R_VYYWFVMS",
                        "VISION.DSE_A_GKDGBHBR",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.PJO_R_EFKGXBCN"
                    ]
                }
            },
            {
                "name": "XXXJIATIW",
                "label": "Study fill.",
                "script": "theory.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJYXVXW",
                "label": "Defense water.",
                "script": "create.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJPUWOI",
                "label": "Us history.",
                "script": "himself.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJUTEWL",
                "label": "Understand top.",
                "script": "series.ksh",
                "dep": {
                    "upr": [
                        "XXXJYXVXW"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJJIFPH , XXXJIATIW ; , XXXJPUWOI ;XXXJIATIW , XXXJYXVXW ;XXXJPUWOI , XXXJUTEWL ;;; "
    },
    "XXXJZSCVBF": {
        "inputs": [
            "XXXJTFQHDL",
            "XXXJZMANJY"
        ],
        "outputs": [
            "XXXJNVSFXW",
            "XXXJVYPKUA",
            "XXXJALBXWD",
            "XXXJHWPKNB"
        ],
        "name": "XXXJZSCVBF",
        "label": "Building too why likely agree.",
        "uprocs": [
            {
                "name": "XXXJTSMVS",
                "label": "Task.",
                "script": "ground.ksh",
                "dep": {
                    "upr": [
                        "XXXJBUZWB"
                    ]
                },
                "table_deps": {
                    "INTER.GVV_T_QCVGBRW": [
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJZKEID",
                "label": "Like.",
                "script": "information.ksh",
                "dep": {
                    "upr": [
                        "XXXJTSMVS"
                    ]
                },
                "table_deps": {
                    "INTER.FYA_T_ITTRZUF": [
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.FXY_F_QMJHIEML",
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJWERFV",
                "label": "Bit.",
                "script": "industry.ksh",
                "dep": {
                    "upr": [
                        "XXXJTSMVS"
                    ]
                },
                "table_deps": {
                    "INTER.KUJ_T_SFPOKWN": [
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.ONV_R_JDNMOSCF",
                        "VISION.EJH_A_PBTTHZET"
                    ]
                }
            },
            {
                "name": "XXXJMIISL",
                "label": "Hear.",
                "script": "certainly.ksh",
                "dep": {
                    "upr": [
                        "XXXJWERFV"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJPDABF",
                "label": "Time.",
                "script": "president.ksh",
                "dep": {
                    "upr": [
                        "XXXJZKEID",
                        "XXXJMIISL"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJQRWWW",
                "label": "Pay so.",
                "script": "hear.ksh",
                "dep": {
                    "upr": [
                        "XXXJTSMVS"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJWHBCJ",
                "label": "Central piece.",
                "script": "strong.ksh",
                "dep": {
                    "upr": [
                        "XXXJTSMVS",
                        "XXXJZMANJY"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMIVOJ",
                "label": "American student.",
                "script": "drive.ksh",
                "dep": {
                    "upr": [
                        "XXXJWHBCJ"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJEDAPG",
                "label": "State.",
                "script": "system.ksh",
                "dep": {
                    "upr": [
                        "XXXJQRWWW",
                        "XXXJMIVOJ"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJPOCKR",
                "label": "Forget.",
                "script": "together.ksh",
                "dep": {
                    "upr": [
                        "XXXJQRWWW",
                        "XXXJMIVOJ"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMXBTL",
                "label": "We share.",
                "script": "skin.ksh",
                "dep": {
                    "upr": [
                        "XXXJEDAPG",
                        "XXXJPOCKR"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJIRNJW",
                "label": "Every.",
                "script": "trial.ksh",
                "dep": {
                    "upr": [
                        "XXXJMXBTL",
                        "XXXJPDABF"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJTSMVS , XXXJZKEID ; , XXXJWERFV ; , XXXJQRWWW ; , XXXJWHBCJ ;XXXJWERFV , XXXJMIISL ;XXXJMIISL , XXXJPDABF ;XXXJWHBCJ , XXXJMIVOJ ;XXXJMIVOJ , XXXJEDAPG ; , XXXJPOCKR ;XXXJPOCKR , XXXJMXBTL ;XXXJMXBTL , XXXJIRNJW ;;; "
    },
    "XXXJHEBIOV": {
        "inputs": [
            "XXXJYGYLBP"
        ],
        "outputs": [
            "XXXJGSACLH"
        ],
        "name": "XXXJHEBIOV",
        "label": "Director event set try.",
        "uprocs": [
            {
                "name": "XXXJRQRJX",
                "label": "Across arrive.",
                "script": "professor.ksh",
                "dep": {
                    "upr": [
                        "XXXJSLSPZ"
                    ]
                },
                "table_deps": {
                    "INTER.DYR_T_RCNYAJQ": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.ZNF_R_QZQTENZM",
                        "BASE.XZK_F_IHGDDHGG",
                        "VISION.EJH_A_PBTTHZET"
                    ]
                }
            },
            {
                "name": "XXXJUWMPJ",
                "label": "Religious.",
                "script": "detail.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJIRHJJ",
                "label": "Against concern.",
                "script": "ask.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJZPWDY",
                "label": "Identify include.",
                "script": "religious.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJKFIJM",
                "label": "Cup.",
                "script": "during.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJJNFVQ",
                "label": "Mr number.",
                "script": "trip.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJEYGAS",
                "label": "Political action.",
                "script": "until.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJXQEPX",
                "label": "Story.",
                "script": "almost.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {}
            },
            {
                "name": "XXXJKAMYQ",
                "label": "Stop.",
                "script": "local.ksh",
                "dep": {
                    "upr": [
                        "XXXJIRHJJ",
                        "XXXJZPWDY",
                        "XXXJKFIJM",
                        "XXXJJNFVQ",
                        "XXXJEYGAS"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJRQRJX , XXXJUWMPJ ; , XXXJXQEPX ;XXXJUWMPJ , XXXJIRHJJ ; , XXXJZPWDY ; , XXXJKFIJM ; , XXXJJNFVQ ; , XXXJEYGAS ;XXXJXQEPX , XXXJKAMYQ ;;; "
    },
    "XXXJBOJLCT": {
        "inputs": [
            "XXXJLUDRXD"
        ],
        "outputs": [
            "XXXJVOCYGI"
        ],
        "name": "XXXJBOJLCT",
        "label": "Store produce amount do student down tend.",
        "uprocs": [
            {
                "name": "XXXJWFSFU",
                "label": "Record.",
                "script": "could.ksh",
                "dep": {
                    "upr": [
                        "XXXJMPHWO"
                    ]
                },
                "table_deps": {
                    "INTER.LVC_T_ZAXZOUT": [
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.ROS_R_QPMFUQVM"
                    ]
                }
            },
            {
                "name": "XXXJENYYS",
                "label": "Science.",
                "script": "wall.ksh",
                "dep": {
                    "upr": [
                        "XXXJWFSFU"
                    ]
                },
                "table_deps": {
                    "INTER.GUV_T_VUXWKPR": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.ZNF_R_QZQTENZM",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJGSHNU",
                "label": "By.",
                "script": "produce.ksh",
                "dep": {
                    "upr": [
                        "XXXJENYYS"
                    ]
                },
                "table_deps": {
                    "INTER.NCT_T_WGJQWXQ": [
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.XZK_F_IHGDDHGG",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            }
        ],
        "plan_ordo_pere_fils": " XXXJWFSFU , XXXJENYYS ;XXXJENYYS , XXXJGSHNU ;;; "
    },
    "XXXJTFQHDL": {
        "inputs": [
            "XXXJHBOCQC",
            "XXXJNVSFXW",
            "XXXJVYPKUA",
            "XXXJVOCYGI"
        ],
        "outputs": [
            "XXXJZMANJY",
            "XXXJZSCVBF",
            "XXXJMYWBPH"
        ],
        "name": "XXXJTFQHDL",
        "label": "Write eat assume event loss lose.",
        "uprocs": [
            {
                "name": "XXXJTZGFZ",
                "label": "System sort.",
                "script": "market.ksh",
                "dep": {
                    "upr": [
                        "XXXJCISGE"
                    ]
                },
                "table_deps": {
                    "INTER.HTB_T_TSIFPBT": [
                        "BASE.ELE_R_VYYWFVMS",
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.DSE_A_GKDGBHBR",
                        "VISION.KKJ_A_FQELHEJF",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.FFB_F_RQHDIGBN",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.UOC_F_QMTYPUVF"
                    ]
                }
            },
            {
                "name": "XXXJLVIAE",
                "label": "Hope without.",
                "script": "where.ksh",
                "dep": {
                    "upr": [
                        "XXXJTZGFZ"
                    ]
                },
                "table_deps": {
                    "INTER.YFY_T_ROBJFNW": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.UOC_F_QMTYPUVF",
                        "BASE.PJO_R_EFKGXBCN"
                    ]
                }
            },
            {
                "name": "XXXJBUZWB",
                "label": "Usually common.",
                "script": "significant.ksh",
                "dep": {
                    "upr": [
                        "XXXJLVIAE"
                    ]
                },
                "table_deps": {
                    "INTER.BZD_T_SNRPCDG": [
                        "BASE.QWJ_R_NIQXWDSX",
                        "BASE.ZNF_R_QZQTENZM",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.BBR_F_UUBFZAGG"
                    ]
                }
            },
            {
                "name": "XXXJJIQWJ",
                "label": "Benefit by.",
                "script": "reveal.ksh",
                "dep": {
                    "upr": [
                        "XXXJBUZWB",
                        "XXXJMHQUC",
                        "XXXJNUDRY",
                        "XXXJFRHOP"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJDKSIH",
                "label": "Her involve.",
                "script": "thank.ksh",
                "dep": {
                    "upr": [
                        "XXXJJIQWJ"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJYVFWO",
                "label": "Mouth fill.",
                "script": "day.ksh",
                "dep": {
                    "upr": [
                        "XXXJBUZWB"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJTZGFZ , XXXJLVIAE ;XXXJLVIAE , XXXJBUZWB ;XXXJBUZWB , XXXJJIQWJ ; , XXXJYVFWO ;XXXJJIQWJ , XXXJDKSIH ;;; "
    },
    "XXXJLUDRXD": {
        "inputs": [],
        "outputs": [
            "XXXJBOJLCT"
        ],
        "name": "XXXJLUDRXD",
        "label": "Not science seem my above tell recent far.",
        "uprocs": [
            {
                "name": "XXXJTYFCM",
                "label": "Election still.",
                "script": "whose.ksh",
                "dep": {
                    "upr": []
                },
                "table_deps": {
                    "INTER.YWN_T_IGYYNXD": [
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.ONV_R_JDNMOSCF"
                    ]
                }
            },
            {
                "name": "XXXJUTFFV",
                "label": "Company ask.",
                "script": "group.ksh",
                "dep": {
                    "upr": [
                        "XXXJTYFCM"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMPHWO",
                "label": "Forget public.",
                "script": "have.ksh",
                "dep": {
                    "upr": [
                        "XXXJUTFFV"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJTYFCM , XXXJUTFFV ;XXXJUTFFV , XXXJMPHWO ;;; "
    },
    "XXXJNVSFXW": {
        "inputs": [
            "XXXJZSCVBF"
        ],
        "outputs": [
            "XXXJTFQHDL",
            "XXXJHBOCQC",
            "XXXJMYWBPH",
            "XXXJYGYLBP"
        ],
        "name": "XXXJNVSFXW",
        "label": "Stock environment particularly small interest that.",
        "uprocs": [
            {
                "name": "XXXJLSJPC",
                "label": "Themselves well.",
                "script": "indicate.ksh",
                "dep": {
                    "upr": [
                        "XXXJPDABF"
                    ]
                },
                "table_deps": {
                    "INTER.YWK_T_RZZWOMU": [
                        "BASE.TWV_R_FKJIDEIR",
                        "BASE.USN_R_KRDRVOJK",
                        "BASE.FXY_F_QMJHIEML",
                        "VISION.EJH_A_PBTTHZET",
                        "BASE.ONV_R_JDNMOSCF",
                        "BASE.OWN_R_RNFYEAIM",
                        "BASE.BBR_F_UUBFZAGG",
                        "BASE.ROS_R_QPMFUQVM",
                        "BASE.PJO_R_EFKGXBCN"
                    ]
                }
            },
            {
                "name": "XXXJNVSFXW",
                "label": "Tell herself.",
                "script": "do.ksh",
                "dep": {
                    "upr": [
                        "XXXJLSJPC"
                    ]
                },
                "table_deps": {}
            },
            {
                "name": "XXXJMHQUC",
                "label": "Sometimes.",
                "script": "describe.ksh",
                "dep": {
                    "upr": [
                        "XXXJNVSFXW"
                    ]
                },
                "table_deps": {}
            }
        ],
        "plan_ordo_pere_fils": " XXXJLSJPC , XXXJNVSFXW ;XXXJNVSFXW , XXXJMHQUC ;;; "
    }
}"""





json_data = json.loads(data)

def plot_network_graph(drug_interactions):
    nodes = list(drug_interactions.keys())
    edges = [(src, dest) for src, destinations in drug_interactions.items() for dest in destinations]

    G = nx.DiGraph()
    G.add_nodes_from(nodes)
    G.add_edges_from(edges)

    nt = Network(height="400px", width="100%", bgcolor="#222222", font_color="white")

    for node in nodes:
        nt.add_node(node, title=node, color="#FF0000")  # Red color for nodes

    for src, dest in edges:
        nt.add_edge(src, dest, arrows="to", color="#87CEFA")  # Black color for arrows

    nt.barnes_hut(gravity=-8000, central_gravity=0.3, spring_length=200, spring_strength=0.01, damping=0.09)

    # Save and read graph as HTML file (locally)
    path = '/html_files'
    nt.save_graph(f'{path}/pyvis_graph.html')
    HtmlFile = open(f'{path}/pyvis_graph.html', 'r', encoding='utf-8')

    # Load HTML file in HTML component for display on Streamlit page
    st.components.html(HtmlFile.read(), height=435)

# Main Streamlit app
def main():
    # Set header title
    st.title('Network Graph Visualization of Drug-Drug Interactions')

    # Implement multiselect dropdown menu for option selection (returns a list)
    selected_drugs = st.multiselect('Select drug(s) to visualize', list(json_data.keys()))

    # Set info message on initial site load
    if len(selected_drugs) == 0:
        st.text('Choose at least 1 drug to start')
    else:
        drug_interactions = {drug: json_data[drug] for drug in selected_drugs}
        plot_network_graph(drug_interactions)

    # Footer
    st.markdown(
        """
        <br>
        <h6>Disclaimer: This app is NOT intended to provide any form of medical advice or recommendations. Please consult your doctor or pharmacist for professional advice relating to any drug therapy.</h6>
        """, unsafe_allow_html=True
    )

if __name__ == "__main__":
    main()
# Out:
# 2023-07-27 16:21:28.779
# ...
#   command:
#
#     streamlit run C:\Users\alarouci\AppData\Local\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
